# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('westworld.csv')

# %%
data
# Out:
#          id                                                url  \
# 0    869671  https://www.tvmaze.com/episodes/869671/westwor...
# 1    911201  https://www.tvmaze.com/episodes/911201/westwor...
# 2    911204  https://www.tvmaze.com/episodes/911204/westwor...
# 3    911205  https://www.tvmaze.com/episodes/911205/westwor...
# 4    927174  https://www.tvmaze.com/episodes/927174/westwor...
# 5    932057  https://www.tvmaze.com/episodes/932057/westwor...
# 6    938404  https://www.tvmaze.com/episodes/938404/westwor...
# 7    943065  https://www.tvmaze.com/episodes/943065/westwor...
# 8    943066  https://www.tvmaze.com/episodes/943066/westwor...
# 9    943067  https://www.tvmaze.com/episodes/943067/westwor...
# 10  1214222  https://www.tvmaze.com/episodes/1214222/westwo...
# 11  1440915  https://www.tvmaze.com/episodes/1440915/westwo...
# 12  1440916  https://www.tvmaze.com/episodes/1440916/westwo...
# 13  1440917  https://www.tvmaze.com/episodes/1440917/westwo...
# ...

# %%
data.shape
# Out:
# (36, 13)

# %% [markdown]
# # ● Get all the overall ratings for each season and using plots compare the ratings for all the  seasons, like season 1 ratings, season 2, and so on.

# %%
data1 = data.groupby('season').mean()['avg_rating'].reset_index()
data1
# Out:
#    season  avg_rating
# 0       1      8.0900
# 1       2      8.0000
# 2       3      7.7750
# 3       4      7.5375

# %%
# barplot
plt.figure(figsize=(7,5))
sns.barplot(x=data1['season'], y=data1['avg_rating'])
plt.show()

# %%
# Line plot
plt.plot(data1['season'], data1['avg_rating'], marker='o', linestyle='-', color='blue')
plt.title('Average Ratings by Season')
plt.xlabel('Season')
plt.ylabel('Average Rating')
plt.show()

# %% [markdown]
# # ● Get all the episode names, whose average rating is more than 8 for every season

# %%
data2 = data[data['avg_rating'] > 8][['name','avg_rating']]
data2
# Out:
#                          name  avg_rating
# 6               Trompe L'Oeil         8.6
# 8   The Well-Tempered Clavier         8.5
# 9          The Bicameral Mind         8.7
# 17                    Kiksuya         8.7
# 18            Vanishing Point         8.4
# 19              The Passenger         8.5

# %% [markdown]
# # ● Get all the episode names that aired before May 2019

# %%
data['airdate'] = pd.to_datetime(data['airdate'], format='%Y-%m-%d')

# %%
names = data[data['airdate'] < pd.Timestamp(2019, 5, 1)]['name']
names
# Out:
# 0                  The Original
# 1                      Chestnut
# 2                     The Stray
# 3             Dissonance Theory
# 4                   Contrapasso
# 5                 The Adversary
# 6                 Trompe L'Oeil
# 7                   Trace Decay
# 8     The Well-Tempered Clavier
# 9            The Bicameral Mind
# 10           Journey Into Night
# 11                      Reunion
# 12              Virtù e Fortuna
# 13     The Riddle of the Sphinx
# 14                 Akane No Mai
# 15                  Phase Space
# 16                 Les Écorchés
# 17                      Kiksuya
# 18              Vanishing Point
# 19                The Passenger
# Name: name, dtype: object

# %% [markdown]
# # ● Get the episode name from each season with the highest and lowest rating

# %%
grouped_data = data.groupby('season')
seasons=[]
highest_rated=[]
lowest_rated=[]
episode_high=[]
episode_low=[]

for i,j in grouped_data:              # Iterate over each group
    
    # Find the episode with the highest rating in each season
    max_rating = j['avg_rating'].idxmax()
    highest_rating = j.loc[max_rating, 'avg_rating']
    episode_highest = j.loc[max_rating, 'name']
    
    # Find the episode eith the lowest rating in each season
    min_rating = j['avg_rating'].idxmin()
    lowest_rating = j.loc[min_rating, 'avg_rating']
    episode_lowest = j.loc[min_rating,'name']
    
    seasons.append(i)
    highest_rated.append(highest_rating)
    episode_high.append(episode_highest)
    lowest_rated.append(lowest_rating)
    episode_low.append(episode_lowest)
    
final_df = pd.DataFrame({
    'season' : seasons,
    'highest_rating' : highest_rated,
    'episode with highest rating' : episode_high,
    'lowest_rating' : lowest_rated,
    'episode with lowest rating' : episode_low
})

# %%
final_df
# Out:
#    season  highest_rating episode with highest rating  lowest_rating  \
# 0       1             8.7          The Bicameral Mind            7.6
# 1       2             8.7                     Kiksuya            7.6
# 2       3             8.0                Parce Domine            7.5
# 3       4             7.8                    Zhuangzi            7.1
#
#   episode with lowest rating
# 0                  The Stray
# 1               Akane No Mai
# 2                Decoherence
# 3               The Auguries

# %% [markdown]
# # ● Get the summary for the most popular ( ratings ) episode in every season

# %%
grouped_data = data.groupby('season')
max_ratings_index = grouped_data['avg_rating'].idxmax()
highest_rated_episode = data.loc[max_ratings_index, ['season','name','avg_rating','summary']]

# %%
highest_rated_episode
# Out:
#     season                name  avg_rating  \
# 9        1  The Bicameral Mind         8.7
# 17       2             Kiksuya         8.7
# 20       3        Parce Domine         8.0
# 32       4            Zhuangzi         7.8
#
#                                               summary
# 9   Delores finds out the truth about William's fa...
# 17  Another of Westworld's Host revolutionaries is...
# 20  If you're stuck in a loop, try walking in a st...
# 32                                      God is bored.
